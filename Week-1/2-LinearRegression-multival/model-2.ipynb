# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv('startup-data-2.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  118671.40       110594.11        294919.57  146121.95
# 11  114523.61       122616.84        261776.23  144259.40
# 12  113867.30        93863.75        249839.44  141585.52
# 13  111313.02        91790.61        252664.93  140122.28
# 14  105582.39       127320.38        249744.55  139020.65
# ...

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['R&D Spend', 'Administration', 'Marketing Spend']], df['Profit'])
# Out:
# LinearRegression()

# %%
reg.predict([[25000.30,65000.80,95000.45]])
# Out:
# D:\softwares\Anaconda-Setup\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72702.15424087])

# %%
reg.coef_
# Out:
# array([ 0.75776181, -0.00801782,  0.03196469])

# %%
reg.intercept_
# Out:
# np.float64(51242.38683933222)

# %%
0.75776181*25000.30+-0.00801782*65000.80+95000.45*0.03196469+51242.38683933222
# Out:
# 72702.15463772972

# %%
test=pd.read_csv('test-data-2.csv')
test
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    95000.50       120000.75        280000.40
# 1    87000.10       112000.60        240000.00
# 2    76000.00        99000.45        210000.30
# 3    62000.25       104000.80        160000.90
# 4   115000.75       131000.20        330000.60
# 5    47000.40        94000.10        110000.50
# 6    32000.60        72000.30         85000.20
# 7   128000.90       142000.55        360000.75
# 8    52000.35        86000.65        125000.45
# 9    15000.00        52000.00         45000.00
# 10  102000.40       118000.25        295000.60
# 11   69000.75        98000.90        175000.25
# 12   58000.60        91000.45        155000.80
# 13  134000.20       149000.60        400000.90
# 14   81000.30       109000.75        230000.40
# 15   27000.45        68000.20         98000.60
# 16   92000.80       116000.35        265000.10
# 17   43000.25        87000.90        140000.70
# 18  140000.60       138000.40        410000.80
# ...

# %%
p=reg.predict(test)

# %%
test['Profit']=p

# %%
test.to_csv('result-2.csv')
