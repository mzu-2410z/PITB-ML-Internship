# %%
import pickle

# %%
with open('model-pickle', 'rb') as f:
    model = pickle.load(f)

# %%
model.predict([[3300]])
# Out:
# D:\softwares\Anaconda-Setup\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])
